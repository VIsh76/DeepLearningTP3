# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))
# Out:
# Using TensorFlow backend.

# %%
skvideo.io.vwrite('test.mp4',  np.random.uniform(0,255,size=(100,100,100)))
HTML(display_videos('test.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
import skvideo.io
import skvideo.datasets
bbb = skvideo.datasets.bigbuckbunny()
print('bigbuckbunny is in: {}'.format(bbb))
v = skvideo.io.vread(filename)
print('shape is: {}'.format(v.shape))
# Out:
# bigbuckbunny is in: /home/victor/.local/lib/python3.6/site-packages/skvideo/datasets/data/bigbuckbunny.mp4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fe06e3fc6b9b> in <module>
#       3 bbb = skvideo.datasets.bigbuckbunny()
#       4 print('bigbuckbunny is in: {}'.format(bbb))
# ----> 5 v = skvideo.io.vread(filename)
#       6 print('shape is: {}'.format(v.shape))
#
# NameError: name 'filename' is not defined
